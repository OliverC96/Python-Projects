# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')
print(df_apps.shape)
print(df_apps.columns)
df_apps.head()
# Out:
# (10841, 12)
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                          App         Category  Rating  Reviews  Size_MBs  \
# 8              cronometra-br     PRODUCTIVITY     NaN        0      5.40
# 101      Wallpapers FN F2000  PERSONALIZATION     NaN        0     11.00
# 680                 dy n fly        LIFESTYLE     NaN        1      4.80
# 326    Clinical Pharmacology          MEDICAL     NaN        0      3.60
# 10749         Microsoft Word     PRODUCTIVITY    4.50  2084125      4.00
#
#           Installs  Type    Price Content_Rating           Genres  \
# 8                0  Paid  $154.99       Everyone     Productivity
# 101              5  Free        0           Teen  Personalization
# 680             50  Free        0       Everyone        Lifestyle
# 326             10  Free        0       Everyone          Medical
# 10749  500,000,000  Free        0       Everyone     Productivity
#
#             Last_Updated Android_Ver
# 8      November 24, 2017  4.1 and up
# 101       April 16, 2018  4.1 and up
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(["Last_Updated", "Android_Ver"], inplace=True, axis=1)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.sample(5)
# Out:
#                                                  App         Category  Rating  \
# 2574                     Weapon AK-74 Live Wallpaper  PERSONALIZATION    3.30
# 1908                    Join R, Community Engagement           SOCIAL    4.70
# 7326  Fat No More - Be the Biggest Loser in the Gym!           FAMILY    3.80
# 8027                              Learn 50 languages        EDUCATION    4.40
# 6795                     X-Plane 10 Flight Simulator           FAMILY    4.20
#
#       Reviews  Size_MBs   Installs  Type Price Content_Rating           Genres
# 2574       25     46.00      1,000  Free     0       Everyone  Personalization
# 1908      144     12.00      1,000  Free     0           Teen           Social
# 7326    48545     38.00  1,000,000  Free     0       Everyone           Casual
# 8027    55256     14.00  5,000,000  Free     0       Everyone        Education
# 6795    63197     11.00  1,000,000  Free     0       Everyone       Simulation

# %%
df_apps.Rating.isna().sum()
# Out:
# 1474

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
# Out:
# 476

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]

# %%
duplicated_rows.shape
# Out:
# (476, 10)

# %%
df_apps_clean.drop_duplicates(subset=["App", "Type", "Price"], inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df_apps_clean[df_apps_clean.App == "Instagram"]
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values("Rating", ascending=False)[["App", "Rating"]]
# Out:
#                                           App  Rating
# 21                        KBA-EZ Health Guide    5.00
# 1230                             Sway Medical    5.00
# 1227                        AJ Men's Grooming    5.00
# 1224                           FK Dedinje BGD    5.00
# 1223                          CB VIDEO VISION    5.00
# ...                                       ...     ...
# 1314                              CR Magazine    1.00
# 1932           FE Mechanical Engineering Prep    1.00
# 357                         Speech Therapy: F    1.00
# 818   Familial Hypercholesterolaemia Handbook    1.00
# 1208                           Thistletown CI    1.00
#
# [8199 rows x 2 columns]

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values("Size_MBs", ascending=False)[["App", "Size_MBs"]]
# The upper limit in app size on the Google Play Store appears to be 100 MBs.
# Out:
#                                   App  Size_MBs
# 9942   Talking Babsy Baby: Baby Games    100.00
# 10687          Hungry Shark Evolution    100.00
# 9943            Miami crime simulator    100.00
# 9944     Gangster Town: Vice District    100.00
# 3144                       Vi Trainer    100.00
# ...                               ...       ...
# 2648      Ad Remove Plugin for App2SD      0.02
# 5798                 ExDialer PRO Key      0.02
# 2684     My baby firework (Remove ad)      0.01
# 7966             Market Update Helper      0.01
# 4696              Essential Resources      0.01
#
# [8199 rows x 2 columns]

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values("Reviews", ascending=False)[["App", "Reviews", "Type"]]
# Out:
#                                                   App   Reviews  Type
# 10805                                        Facebook  78158306  Free
# 10785                              WhatsApp Messenger  69119316  Free
# 10806                                       Instagram  66577313  Free
# 10784        Messenger – Text and Video Chat for Free  56642847  Free
# 10650                                  Clash of Clans  44891723  Free
# ...                                               ...       ...   ...
# 453                               Wowkwis aq Ka'qaquj         1  Free
# 462                                            CB Fit         1  Free
# 901                   ES Billing System (Offline App)         1  Free
# 1416   Ek Kahani Aisi Bhi Season 3 - The Horror Story         1  Free
# 1100                                     Chenoweth AH         1  Free
#
# [8199 rows x 3 columns]

# %%
df_apps_clean.sort_values("Reviews", ascending=False)[["App", "Reviews", "Type"]][:50][df_apps_clean.Type == 'Paid'].count()
# Therefore, there are no paid apps within the top 50 most reviewed apps on the Google Play Store
# Out:
# <ipython-input-22-22450a082b26>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_apps_clean.sort_values("Reviews", ascending=False)[["App", "Reviews", "Type"]][:50][df_apps_clean.Type == 'Paid'].count()
# App        0
# Reviews    0
# Type       0
# dtype: int64

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
import plotly.express as px

# %%
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, names=ratings.index, title="Content Rating")
fig.update_traces(textposition="outside", textinfo="percent+label")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
donut = px.pie(labels=ratings.index, values=ratings.values, names=ratings.index, title="Content Rating", hole=0.6)
donut.update_traces(textposition="inside", textfont_size=15, textinfo="percent")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.Installs.describe()
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 962.6+ KB

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(",", "")
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)

# %%
df_apps_clean[["App", "Installs"]].groupby("Installs").count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace("$", "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
df_apps_clean.sort_values("Price", ascending=False).head(20)
# Out:
# <ipython-input-31-7ffddfa410ba>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# ...

# %%
df_apps_clean = df_apps_clean[df_apps_clean.Price <= 250]

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean.sort_values("Price", ascending=False).head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 1407               LTC AS Legal    MEDICAL    4.00        6      1.30
# 2629           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 2481    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 2463         PTA Content Master    MEDICAL    4.20       64     41.00
#
#       Installs  Type  Price Content_Rating     Genres
# 2281      1000  Paid  79.99       Everyone    Medical
# 1407       100  Paid  39.99       Everyone    Medical
# 2629      1000  Paid  37.99       Everyone  Lifestyle
# 2481      1000  Paid  33.99       Everyone    Medical
# 2463      1000  Paid  29.99       Everyone    Medical

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean.insert(1, "Revenue_Estimate", df_apps_clean.Installs*df_apps_clean.Price)
df_apps_clean.sort_values("Revenue_Estimate", ascending=False).head(10)
# Out:
#                                 App  Revenue_Estimate     Category  Rating  \
# 9220                      Minecraft     69,900,000.00       FAMILY    4.50
# 8825                  Hitman Sniper      9,900,000.00         GAME    4.60
# 7151  Grand Theft Auto: San Andreas      6,990,000.00         GAME    4.40
# 7477            Facetune - For Free      5,990,000.00  PHOTOGRAPHY    4.40
# 7977        Sleep as Android Unlock      5,990,000.00    LIFESTYLE    4.50
# 6594            DraStic DS Emulator      4,990,000.00         GAME    4.60
# 6082                   Weather Live      2,995,000.00      WEATHER    4.50
# 7954                    Bloons TD 5      2,990,000.00       FAMILY    4.60
# 7633        Five Nights at Freddy's      2,990,000.00         GAME    4.60
# 6746     Card Wars - Adventure Time      2,990,000.00       FAMILY    4.30
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 9220  2376564     19.00  10000000  Paid   6.99   Everyone 10+
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
categories = df_apps_clean.Category.value_counts()[:10]
categories
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %%
bar = px.bar(x=categories.index, y=categories.values)
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
category_installs = df_apps_clean.groupby("Category").agg({"Installs":pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
h_bar = px.bar(x=category_installs.Installs, y=category_installs.index, orientation='h', title="Category Popularity")
h_bar.update_layout(xaxis_title="Number of Downloads", yaxis_title="Categories")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
apps = df_apps_clean.groupby("Category").count()["App"]
apps
# Out:
# Category
# ART_AND_DESIGN           61
# AUTO_AND_VEHICLES        73
# BEAUTY                   42
# BOOKS_AND_REFERENCE     169
# BUSINESS                262
# COMICS                   54
# COMMUNICATION           257
# DATING                  134
# EDUCATION               118
# ENTERTAINMENT           102
# EVENTS                   45
# FAMILY                 1606
# FINANCE                 296
# FOOD_AND_DRINK           94
# GAME                    910
# HEALTH_AND_FITNESS      243
# HOUSE_AND_HOME           62
# LIBRARIES_AND_DEMO       64
# LIFESTYLE               297
# MAPS_AND_NAVIGATION     118
# MEDICAL                 292
# NEWS_AND_MAGAZINES      204
# PARENTING                50
# PERSONALIZATION         298
# PHOTOGRAPHY             263
# PRODUCTIVITY            301
# SHOPPING                180
# SOCIAL                  203
# SPORTS                  260
# TOOLS                   719
# TRAVEL_AND_LOCAL        187
# VIDEO_PLAYERS           148
# ...

# %%
v_bar = px.bar(x=apps.index, y=apps.values, orientation='v', title="Competition by Category")
v_bar.update_layout(xaxis_title="Categories", yaxis_title="Number of Distinct Apps")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
conc = pd.merge(apps, category_installs, on="Category")
conc.sort_values("Installs", ascending=False, inplace=True)
conc.rename(columns={"App": "Apps"}, inplace=True)
conc.head()
# Out:
#                Apps     Installs
# Category
# GAME            910  13858762717
# COMMUNICATION   257  11039241530
# TOOLS           719   8099724500
# PRODUCTIVITY    301   5788070180
# SOCIAL          203   5487841475

# %%
conc_plot = px.scatter(x=conc.Apps, y=conc.Installs, log_y=True, hover_name=conc.index, title='Category Concentration', size=conc.Apps, color=conc.Installs)
conc_plot.update_layout(xaxis_title="Number of Apps (Lower = More Concentrated)", yaxis_title = "Installs")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean.Genres.nunique()
df_apps_clean.Genres.value_counts().sort_values(ascending=True)[:5]
# Out:
# Lifestyle;Pretend Play      1
# Strategy;Education          1
# Adventure;Education         1
# Role Playing;Brain Games    1
# Tools;Education             1
# Name: Genres, dtype: int64

# %%
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
genres = stack.value_counts()

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(x=genres.index[:15], y=genres.values[:15], title="Top Genres", hover_name=genres.index[:15], color=genres.values[:15], color_continuous_scale='Agsunset')
bar.update_layout(xaxis_title="Genre", yaxis_title="Number of Apps", coloraxis_showscale=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_clean.Type.value_counts()
df_types = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({"App":pd.Series.count})
df_types
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
graph = px.bar(x=df_types.Category, y=df_types.App, title="Free vs Paid Apps by Category", color=df_types.Type, barmode="group", log_y=True)
graph.update_layout(xaxis_title="Category", yaxis_title="Number of Apps", xaxis={"categoryorder":"total descending"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box_installs = px.box(df_apps_clean, x="Type", y="Installs", log_y=True, color="Type", notched=True, points="all", title="How Many Downloads are Paid Apps Giving Up?")
box_installs.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_apps_clean.sample(5)
# Out:
#                               App  Revenue_Estimate       Category  Rating  \
# 3148                     BK Dinos              0.00         FAMILY    4.40
# 1830  All Types DP & Status Maker              0.00    PHOTOGRAPHY    4.50
# 4395                     BSPlayer        299,500.00  VIDEO_PLAYERS    4.20
# 7153     Rope Superhero Unlimited              0.00           GAME    4.40
# 6881                   Funny Pics              0.00  ENTERTAINMENT    3.90
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 3148       30     99.00      5000  Free   0.00       Everyone
# 1830       16     14.00      1000  Free   0.00           Teen
# 4395     4585      4.65     50000  Paid   5.99       Everyone
# 7153     6735     26.00   1000000  Free   0.00     Mature 17+
# 6881     9941      9.35   1000000  Free   0.00           Teen
#
#                        Genres
# 3148            Entertainment
# 1830              Photography
# 4395  Video Players & Editors
# ...

# %%
paid_apps = df_apps_clean[df_apps_clean.Type == "Paid"]
revenue_estimate = px.box(paid_apps, x="Category", y="Revenue_Estimate", log_y=True, title="How Much Can Paid Apps Earn?")
revenue_estimate.update_layout(xaxis_title="Category", yaxis_title="Paid App Ballpark Revenue",  xaxis={'categoryorder':'min ascending'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
paid_apps.Price.median()
# Out:
# 2.99

# %%
app_pricing = px.box(paid_apps, x="Category", y="Price", title="Price per Category", log_y=True)

# %%
app_pricing.update_layout(xaxis_title="Category", yaxis_title="Paid Apps Price", xaxis={"categoryorder": "max descending"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
